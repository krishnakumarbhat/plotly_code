# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import pickle

# %%
def load(path):
    with open(path, 'rb') as handle:
        data = pickle.load(handle)
    return data

# %%
full_set = load(r'\\10.224.186.68\AD-Shared\F360\Tools\LogSets\FullSet\fullset_dropped_comps.pickle')
logs_paths = full_set.path
full_set = full_set.drop('path', axis=1)
x = StandardScaler().fit_transform(full_set)
# Out:
# C:\Users\sjrh1c.EUROPE\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\sjrh1c.EUROPE\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
n_components = 3
columns = list()
for c in range(n_components):
    columns.append('PC' + str(c+1))
    
pca = PCA(n_components=n_components)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents, columns = columns)

ratio = pca.explained_variance_ratio_
ratio.shape
explained_variance_ratio_df = pd.DataFrame(pca.explained_variance_ratio_, index=principalDf.columns).T

# %%
principalDf
# Out:
#            PC1        PC2       PC3
# 0    -2.998437  -0.319888 -1.227625
# 1    -6.797654   1.470402  4.009540
# 2    -4.749643   0.453571  2.708257
# 3    -5.053044   0.528746  2.513266
# 4    -5.603520   0.776796  3.863384
# 5    -5.582725   0.950103  3.955766
# 6    -3.404492  -0.455119  1.389136
# 7    -3.797626  -0.558902  1.451365
# 8    -3.971256   1.381876  3.038596
# 9    -4.451654  -0.070092  1.692591
# 10   -4.801232   0.341730  2.388268
# 11   -4.549094   0.520985  0.925456
# 12   -4.584636   0.678928  1.476440
# 13   -5.701231   0.630931  4.154476
# 14   -5.499205   0.677256  3.457594
# 15   -4.273344   0.291882  1.931826
# 16   -4.433914   0.206164  1.414883
# 17   -3.710684   0.384251  1.903693
# 18   -3.991704   0.038818  1.095208
# 19   -5.085795   0.620137  2.437224
# 20   -4.997122   0.484654  2.338160
# 21   -4.687898   0.344569  1.982245
# 22   -4.564851   0.345066  1.673691
# 23   -5.069714   0.578765  2.407317
# 24   -5.517426   0.962038  3.268857
# ...

# %%
explained_variance_ratio_df
# Out:
#         PC1       PC2       PC3
# 0  0.418619  0.151015  0.065869

# %%
# remaining information
sum(pca.explained_variance_ratio_)
# Out:
# 0.6355031117157521

# %%
df_comp = pd.DataFrame(abs(pca.components_), columns=full_set.columns, index=columns).T
pca_interpretation = df_comp.sort_values(by=['PC1'], axis=0, ascending=False)
pca_interpretation
# Out:
#                                                       PC1       PC2       PC3
# min_num_of_Truck                                 0.131661  0.017697  0.061890
# mean_movable_objs_speed_spread                   0.129910  0.032926  0.096532
# max_moving_objs_point_angle_spread               0.128565  0.003628  0.047588
# max_num_objs                                     0.127254  0.077170  0.082872
# max_num_moving_objs                              0.127213  0.073506  0.040844
# max_num_movable_unique_objs_conf_lvl_0.95-0.99   0.127010  0.085947  0.029468
# max_movable_objs_speed_spread                    0.126668  0.002047  0.080908
# max_num_movable_unique_objs_conf_lvl_0.5-0.7     0.126519  0.067017  0.024237
# max_num_movable_unique_objs_conf_lvl_0.9-0.95    0.126275  0.085065  0.031100
# max_num_movable_unique_objs_conf_lvl_0.3-0.5     0.125256  0.053607  0.036300
# max_num_movable_unique_objs_conf_lvl_0.7-0.9     0.125154  0.084720  0.026148
# ...

# %%
df_comp = pd.DataFrame(abs(pca.components_), columns=full_set.columns, index=columns).T
pca_interpretation = df_comp.sort_values(by=['PC2'], axis=0, ascending=False)
pca_interpretation
# Out:
#                                                          PC1       PC2  \
# mean_num_stat_movable_objs                          0.086833  0.152440
# mean_num_of_Motorcycle                              0.077650  0.151398
# mean_num_objs_distance_40-90m                       0.080739  0.149785
# max_num_of_Motorcycle                               0.084858  0.149478
# max_num_moving_objs_speed_10-25km/h                 0.093690  0.145721
# max_num_moving_objs_speed_1-5km/h                   0.080343  0.145555
# mean_num_moving_objs_speed_10-25km/h                0.078964  0.144019
# mean_num_moving_objs_speed_0-1km/h                  0.063656  0.141300
# mean_num_moving_objs_speed_5-10km/h                 0.070264  0.141130
# max_num_objs_distance_40-90m                        0.092357  0.140700
# mean_num_moving_objs_speed_1-5km/h                  0.064571  0.140574
# max_num_moving_objs_speed_0-1km/h                   0.082897  0.140508
# ...

# %%
df_comp = pd.DataFrame(abs(pca.components_), columns=full_set.columns, index=columns).T
pca_interpretation = df_comp.sort_values(by=['PC3'], axis=0, ascending=False)
pca_interpretation
# Out:
#                                                          PC1       PC2  \
# max_num_of_Pedestrian                               0.063917  0.088528
# mean_num_stat_objs_speed_10-25km/h                  0.017548  0.022238
# mean_non_movable_objs_speed_spread                  0.018428  0.008589
# num_unique_objs_lifetime_more200                    0.071857  0.066760
# max_num_stat_objs_speed_10-25km/h                   0.051223  0.038290
# mean_num_moving_objs_point_angle_+-0-2.5degrees     0.100201  0.051538
# mean_num_of_Pedestrian                              0.045296  0.108022
# mean_num_moving_objs_speed_90-120km/h               0.068520  0.104978
# max_num_moving_objs_speed_90-120km/h                0.084797  0.106138
# mean_num_moving_objs_speed_70-90km/h                0.063369  0.090716
# mean_num_stat_objs_speed_5-10km/h                   0.070695  0.086910
# max_num_moving_objs_speed_120-150km/h               0.078640  0.105883
# ...
