# %% [markdown]
# # Checking representativenes of the alpha set

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from matplotlib.pyplot import cm
import warnings
warnings.filterwarnings("ignore", module="matplotlib")

# %%
def load(path):
    with open(path, 'rb') as handle:
        data = pickle.load(handle)
    return data

# %%
# full_set = load(r'\\10.224.186.68\AD-Shared\F360\Tools\LogSets\FullSet\ad_shared_demo\ad_shared_demo.pickle').drop('path', axis=1)
full_set = load(r'\\10.224.186.68\AD-Shared\F360\Tools\LogSets\FullSet\fullset_dropped_comps.pickle').drop('path', axis=1)
# alpha_set = load(r'\\10.224.186.68\AD-Shared\F360\Tools\LogSets\AlphaSets\ad_shared_demo\ad_shared_demo.pickle').drop('path', axis=1)
alpha_set = load(r'\\10.224.186.68\AD-Shared\F360\Tools\LogSets\AlphaSets\alpha_set_25.pickle').drop('path', axis=1)

# %%
# visual prob dist plots analysis 
fig = plt.figure(figsize=(30, 6))
ax = sns.distplot(full_set.iloc[:,67], hist=False, bins=50, label='full')
ax1 = sns.distplot(alpha_set.iloc[:,67], hist=False, bins=50, label='alpha')

# %%
# calculating d-value from kolgomorov-smirnov test
from scipy import stats
p = []
for i in range(full_set.shape[1]):
    p.append(stats.ks_2samp(full_set.iloc[:,i], alpha_set.iloc[:,i])[1])

# %%
np.mean(p)
# Out:
# 0.8321638829219452
